# %% [markdown]
# # DataFrames III: Data Extraction

# %%
import pandas as pd

# %% [markdown]
# ## This Module's Dataset
# - This module's dataset is a collection of all James Bond movies.

# %%
bond = pd.read_csv("jamesbond.csv")
bond
# Out:
#                                Film  Year           Actor            Director  \
# 0                            Dr. No  1962    Sean Connery       Terence Young
# 1             From Russia with Love  1963    Sean Connery       Terence Young
# 2                        Goldfinger  1964    Sean Connery        Guy Hamilton
# 3                       Thunderball  1965    Sean Connery       Terence Young
# 4                     Casino Royale  1967     David Niven          Ken Hughes
# 5               You Only Live Twice  1967    Sean Connery       Lewis Gilbert
# 6   On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# 7              Diamonds Are Forever  1971    Sean Connery        Guy Hamilton
# 8                  Live and Let Die  1973     Roger Moore        Guy Hamilton
# 9       The Man with the Golden Gun  1974     Roger Moore        Guy Hamilton
# 10             The Spy Who Loved Me  1977     Roger Moore       Lewis Gilbert
# 11                        Moonraker  1979     Roger Moore       Lewis Gilbert
# 12               For Your Eyes Only  1981     Roger Moore           John Glen
# 13            Never Say Never Again  1983    Sean Connery      Irvin Kershner
# 14                        Octopussy  1983     Roger Moore           John Glen
# 15                 A View to a Kill  1985     Roger Moore           John Glen
# 16             The Living Daylights  1987  Timothy Dalton           John Glen
# 17                  Licence to Kill  1989  Timothy Dalton           John Glen
# 18                        GoldenEye  1995  Pierce Brosnan     Martin Campbell
# 19              Tomorrow Never Dies  1997  Pierce Brosnan  Roger Spottiswoode
# 20          The World Is Not Enough  1999  Pierce Brosnan       Michael Apted
# 21                  Die Another Day  2002  Pierce Brosnan        Lee Tamahori
# 22                    Casino Royale  2006    Daniel Craig     Martin Campbell
# 23                Quantum of Solace  2008    Daniel Craig        Marc Forster
# 24                          Skyfall  2012    Daniel Craig          Sam Mendes
# 25                          Spectre  2015    Daniel Craig          Sam Mendes
# 26                   No Time to Die  2021    Daniel Craig  Cary Joji Fukunaga
#
#     Box Office  Budget  Bond Actor Salary
# 0        448.8     7.0                0.6
# 1        543.8    12.6                1.6
# 2        820.4    18.6                3.2
# 3        848.1    41.9                4.7
# 4        315.0    85.0                NaN
# 5        514.2    59.9                4.4
# 6        291.5    37.3                0.6
# 7        442.5    34.7                5.8
# 8        460.3    30.8                NaN
# 9        334.0    27.7                NaN
# 10       533.0    45.1                NaN
# 11       535.0    91.5                NaN
# 12       449.4    60.2                NaN
# 13       380.0    86.0                NaN
# 14       373.8    53.9                7.8
# 15       275.2    54.5                9.1
# 16       313.5    68.8                5.2
# 17       250.9    56.7                7.9
# 18       518.5    76.9                5.1
# 19       463.2   133.9               10.0
# 20       439.5   158.3               13.5
# 21       465.4   154.2               17.9
# 22       581.5   145.3                3.3
# 23       514.2   181.4                8.1
# 24       943.5   170.2               14.5
# 25       726.7   206.3               30.0
# 26       774.2   301.0               25.0

# %% [markdown]
# ## The set_index and reset_index Methods
# - The index serves as the collection of primary identifiers/labels/entrypoints for the rows.
# - The fastest way to extract a row is from a sorted index by position/label.
# - Pandas uses index labels/values when merging different objects together.
# - The `set_index` method sets an existing column as the index of the **DataFrame**.
# - The `reset_index` method sets the standard ascending numeric index as the index of the **DataFrame**.

# %% [markdown]
# #### The column that closely represents the 'unique-ness' of the dataset should be set as the index. It significantly helps in lowering the computing power required to fetch any record since you dont have to write out any filtering conditions/ queries
# Fo example, for a customer dataset, it'd be the customerID OR in case of production dataset, the productID etc.
# ##### So in the case of the Bond dataset, the Film Name serves as the unique identifier of each row.

# %%
bond = bond.set_index(["Film"])
bond.head(7)
# Out:
#                                  Year           Actor       Director  \
# Film
# Dr. No                           1962    Sean Connery  Terence Young
# From Russia with Love            1963    Sean Connery  Terence Young
# Goldfinger                       1964    Sean Connery   Guy Hamilton
# Thunderball                      1965    Sean Connery  Terence Young
# Casino Royale                    1967     David Niven     Ken Hughes
# You Only Live Twice              1967    Sean Connery  Lewis Gilbert
# On Her Majesty's Secret Service  1969  George Lazenby  Peter R. Hunt
#
#                                  Box Office  Budget  Bond Actor Salary
# Film
# Dr. No                                448.8     7.0                0.6
# From Russia with Love                 543.8    12.6                1.6
# Goldfinger                            820.4    18.6                3.2
# Thunderball                           848.1    41.9                4.7
# Casino Royale                         315.0    85.0                NaN
# You Only Live Twice                   514.2    59.9                4.4
# On Her Majesty's Secret Service       291.5    37.3                0.6

# %%
# Resetting to default pandas index (numeric index)
bond.reset_index()
# Out:
#                                Film  Year           Actor            Director  \
# 0                            Dr. No  1962    Sean Connery       Terence Young
# 1             From Russia with Love  1963    Sean Connery       Terence Young
# 2                        Goldfinger  1964    Sean Connery        Guy Hamilton
# 3                       Thunderball  1965    Sean Connery       Terence Young
# 4                     Casino Royale  1967     David Niven          Ken Hughes
# 5               You Only Live Twice  1967    Sean Connery       Lewis Gilbert
# 6   On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# 7              Diamonds Are Forever  1971    Sean Connery        Guy Hamilton
# 8                  Live and Let Die  1973     Roger Moore        Guy Hamilton
# 9       The Man with the Golden Gun  1974     Roger Moore        Guy Hamilton
# 10             The Spy Who Loved Me  1977     Roger Moore       Lewis Gilbert
# 11                        Moonraker  1979     Roger Moore       Lewis Gilbert
# 12               For Your Eyes Only  1981     Roger Moore           John Glen
# 13            Never Say Never Again  1983    Sean Connery      Irvin Kershner
# 14                        Octopussy  1983     Roger Moore           John Glen
# 15                 A View to a Kill  1985     Roger Moore           John Glen
# 16             The Living Daylights  1987  Timothy Dalton           John Glen
# 17                  Licence to Kill  1989  Timothy Dalton           John Glen
# 18                        GoldenEye  1995  Pierce Brosnan     Martin Campbell
# 19              Tomorrow Never Dies  1997  Pierce Brosnan  Roger Spottiswoode
# 20          The World Is Not Enough  1999  Pierce Brosnan       Michael Apted
# 21                  Die Another Day  2002  Pierce Brosnan        Lee Tamahori
# 22                    Casino Royale  2006    Daniel Craig     Martin Campbell
# 23                Quantum of Solace  2008    Daniel Craig        Marc Forster
# 24                          Skyfall  2012    Daniel Craig          Sam Mendes
# 25                          Spectre  2015    Daniel Craig          Sam Mendes
# 26                   No Time to Die  2021    Daniel Craig  Cary Joji Fukunaga
#
#     Box Office  Budget  Bond Actor Salary
# 0        448.8     7.0                0.6
# 1        543.8    12.6                1.6
# 2        820.4    18.6                3.2
# 3        848.1    41.9                4.7
# 4        315.0    85.0                NaN
# 5        514.2    59.9                4.4
# 6        291.5    37.3                0.6
# 7        442.5    34.7                5.8
# 8        460.3    30.8                NaN
# 9        334.0    27.7                NaN
# 10       533.0    45.1                NaN
# 11       535.0    91.5                NaN
# 12       449.4    60.2                NaN
# 13       380.0    86.0                NaN
# 14       373.8    53.9                7.8
# 15       275.2    54.5                9.1
# 16       313.5    68.8                5.2
# 17       250.9    56.7                7.9
# 18       518.5    76.9                5.1
# 19       463.2   133.9               10.0
# 20       439.5   158.3               13.5
# 21       465.4   154.2               17.9
# 22       581.5   145.3                3.3
# 23       514.2   181.4                8.1
# 24       943.5   170.2               14.5
# 25       726.7   206.3               30.0
# 26       774.2   301.0               25.0

# %%
# Reset the index and set the Release year as the index
bond = bond.reset_index().set_index(["Year"])
bond.head(7)
# Out:
#                                  Film           Actor       Director  \
# Year
# 1962                           Dr. No    Sean Connery  Terence Young
# 1963            From Russia with Love    Sean Connery  Terence Young
# 1964                       Goldfinger    Sean Connery   Guy Hamilton
# 1965                      Thunderball    Sean Connery  Terence Young
# 1967                    Casino Royale     David Niven     Ken Hughes
# 1967              You Only Live Twice    Sean Connery  Lewis Gilbert
# 1969  On Her Majesty's Secret Service  George Lazenby  Peter R. Hunt
#
#       Box Office  Budget  Bond Actor Salary
# Year
# 1962       448.8     7.0                0.6
# 1963       543.8    12.6                1.6
# 1964       820.4    18.6                3.2
# 1965       848.1    41.9                4.7
# 1967       315.0    85.0                NaN
# 1967       514.2    59.9                4.4
# 1969       291.5    37.3                0.6

# %% [markdown]
# #### If it occurs that this unique-ness can be identified by more than one columns OR there could be some sort of a heirarchy to the unique-ness - a sub-categorization of sorts - then `multi-indexing` could be introduced in the dataset

# %% [markdown]
# ## Retrieve Rows by Index Position with iloc Accessor
# - The `iloc` accessor retrieves one or more rows by index position.
# - Provide a pair of square brackets after the accessor.
# - `iloc` accepts single values, lists, and slices.

# %% [markdown]
# ##### Even if custom index are assigned to a dataframe, pandas will still assign numeric indexes in the backend

# %%
# Importing bond dataset as a new DataFrame 
newbond = pd.read_csv("jamesbond.csv")
newbond.head(7)
# Out:
#                               Film  Year           Actor       Director  \
# 0                           Dr. No  1962    Sean Connery  Terence Young
# 1            From Russia with Love  1963    Sean Connery  Terence Young
# 2                       Goldfinger  1964    Sean Connery   Guy Hamilton
# 3                      Thunderball  1965    Sean Connery  Terence Young
# 4                    Casino Royale  1967     David Niven     Ken Hughes
# 5              You Only Live Twice  1967    Sean Connery  Lewis Gilbert
# 6  On Her Majesty's Secret Service  1969  George Lazenby  Peter R. Hunt
#
#    Box Office  Budget  Bond Actor Salary
# 0       448.8     7.0                0.6
# 1       543.8    12.6                1.6
# 2       820.4    18.6                3.2
# 3       848.1    41.9                4.7
# 4       315.0    85.0                NaN
# 5       514.2    59.9                4.4
# 6       291.5    37.3                0.6

# %%
# Fetching a row by its index location
newbond.iloc[3]
# Out:
# Film                   Thunderball
# Year                          1965
# Actor                 Sean Connery
# Director             Terence Young
# Box Office                   848.1
# Budget                        41.9
# Bond Actor Salary              4.7
# Name: 3, dtype: object

# %%
# Fetching a range (slice) of rows based on index location -- from n to (n-1)
newbond.iloc[3:7]
# Out:
#                               Film  Year           Actor       Director  \
# 3                      Thunderball  1965    Sean Connery  Terence Young
# 4                    Casino Royale  1967     David Niven     Ken Hughes
# 5              You Only Live Twice  1967    Sean Connery  Lewis Gilbert
# 6  On Her Majesty's Secret Service  1969  George Lazenby  Peter R. Hunt
#
#    Box Office  Budget  Bond Actor Salary
# 3       848.1    41.9                4.7
# 4       315.0    85.0                NaN
# 5       514.2    59.9                4.4
# 6       291.5    37.3                0.6

# %%
# Fething more than one rows 
newbond.iloc[[3,5,6,10]]
# Out:
#                                Film  Year           Actor       Director  \
# 3                       Thunderball  1965    Sean Connery  Terence Young
# 5               You Only Live Twice  1967    Sean Connery  Lewis Gilbert
# 6   On Her Majesty's Secret Service  1969  George Lazenby  Peter R. Hunt
# 10             The Spy Who Loved Me  1977     Roger Moore  Lewis Gilbert
#
#     Box Office  Budget  Bond Actor Salary
# 3        848.1    41.9                4.7
# 5        514.2    59.9                4.4
# 6        291.5    37.3                0.6
# 10       533.0    45.1                NaN

# %% [markdown]
# ## Retrieve Rows by Index Label with loc Accessor
# - The `loc` accessor retrieves one or more rows by index label.
# - Provide a pair of square brackets after the accessor.

# %%
bond = bond.reset_index().set_index(["Film"])
bond.head(7)
# Out:
#                                  Year           Actor       Director  \
# Film
# Dr. No                           1962    Sean Connery  Terence Young
# From Russia with Love            1963    Sean Connery  Terence Young
# Goldfinger                       1964    Sean Connery   Guy Hamilton
# Thunderball                      1965    Sean Connery  Terence Young
# Casino Royale                    1967     David Niven     Ken Hughes
# You Only Live Twice              1967    Sean Connery  Lewis Gilbert
# On Her Majesty's Secret Service  1969  George Lazenby  Peter R. Hunt
#
#                                  Box Office  Budget  Bond Actor Salary
# Film
# Dr. No                                448.8     7.0                0.6
# From Russia with Love                 543.8    12.6                1.6
# Goldfinger                            820.4    18.6                3.2
# Thunderball                           848.1    41.9                4.7
# Casino Royale                         315.0    85.0                NaN
# You Only Live Twice                   514.2    59.9                4.4
# On Her Majesty's Secret Service       291.5    37.3                0.6

# %%
# Fetching a single row by loc accessor
bond.loc["Goldfinger"]
# Out:
# Year                         1964
# Actor                Sean Connery
# Director             Guy Hamilton
# Box Office                  820.4
# Budget                       18.6
# Bond Actor Salary             3.2
# Name: Goldfinger, dtype: object

# %%
# Records with same Indexes will output a dataframe copy -- since thet wil be 
bond.loc["Casino Royale"]
# Out:
#                Year         Actor         Director  Box Office  Budget  \
# Film
# Casino Royale  1967   David Niven       Ken Hughes       315.0    85.0
# Casino Royale  2006  Daniel Craig  Martin Campbell       581.5   145.3
#
#                Bond Actor Salary
# Film
# Casino Royale                NaN
# Casino Royale                3.3

# %%
# Fectching multiple rows by passing a list of indexes
bond.loc[["Goldfinger","GoldenEye"]]
# Out:
#             Year           Actor         Director  Box Office  Budget  \
# Film
# Goldfinger  1964    Sean Connery     Guy Hamilton       820.4    18.6
# GoldenEye   1995  Pierce Brosnan  Martin Campbell       518.5    76.9
#
#             Bond Actor Salary
# Film
# Goldfinger                3.2
# GoldenEye                 5.1

# %% [markdown]
# ##### fetching records over a range of index labels is possible but you need to be aware of the sequence of the indexes

# %%
# Fetching multiple records over a range of index labels 
bond.loc["Goldfinger":"Moonraker"]
# Out:
#                                  Year           Actor       Director  \
# Film
# Goldfinger                       1964    Sean Connery   Guy Hamilton
# Thunderball                      1965    Sean Connery  Terence Young
# Casino Royale                    1967     David Niven     Ken Hughes
# You Only Live Twice              1967    Sean Connery  Lewis Gilbert
# On Her Majesty's Secret Service  1969  George Lazenby  Peter R. Hunt
# Diamonds Are Forever             1971    Sean Connery   Guy Hamilton
# Live and Let Die                 1973     Roger Moore   Guy Hamilton
# The Man with the Golden Gun      1974     Roger Moore   Guy Hamilton
# The Spy Who Loved Me             1977     Roger Moore  Lewis Gilbert
# Moonraker                        1979     Roger Moore  Lewis Gilbert
#
#                                  Box Office  Budget  Bond Actor Salary
# Film
# Goldfinger                            820.4    18.6                3.2
# Thunderball                           848.1    41.9                4.7
# Casino Royale                         315.0    85.0                NaN
# You Only Live Twice                   514.2    59.9                4.4
# On Her Majesty's Secret Service       291.5    37.3                0.6
# Diamonds Are Forever                  442.5    34.7                5.8
# Live and Let Die                      460.3    30.8                NaN
# The Man with the Golden Gun           334.0    27.7                NaN
# The Spy Who Loved Me                  533.0    45.1                NaN
# Moonraker                             535.0    91.5                NaN

# %% [markdown]
# #### <mark>**NOTE**</mark> that trying to use non-unique indexes in any filtering operation will result in error since pandas won't be able to determine which to refer as start / end

# %%
bond.loc["Casino Royale":"Casino Royale"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 bond.loc["Casino Royale":"Casino Royale"]
#
# File c:\Users\ABHIJEET.BHAMBERE\Desktop\Resources\pandas_repo\.venv\Lib\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File c:\Users\ABHIJEET.BHAMBERE\Desktop\Resources\pandas_repo\.venv\Lib\site-packages\pandas\core\indexing.py:1411, in _LocIndexer._getitem_axis(self, key, axis)
#    1409 if isinstance(key, slice):
#    1410     self._validate_key(key, axis)
# -> 1411     return self._get_slice_axis(key, axis=axis)
#    1412 elif com.is_bool_indexer(key):
#    1413     return self._getbool_axis(key, axis=axis)
#
# File c:\Users\ABHIJEET.BHAMBERE\Desktop\Resources\pandas_repo\.venv\Lib\site-packages\pandas\core\indexing.py:1443, in _LocIndexer._get_slice_axis(self, slice_obj, axis)
#    1440     return obj.copy(deep=False)
#    1442 labels = obj._get_axis(axis)
# -> 1443 indexer = labels.slice_indexer(slice_obj.start, slice_obj.stop, slice_obj.step)
#    1445 if isinstance(indexer, slice):
#    1446     return self.obj._slice(indexer, axis=axis)
#
# File c:\Users\ABHIJEET.BHAMBERE\Desktop\Resources\pandas_repo\.venv\Lib\site-packages\pandas\core\indexes\base.py:6662, in Index.slice_indexer(self, start, end, step)
#    6618 def slice_indexer(
#    6619     self,
#    6620     start: Hashable | None = None,
#    6621     end: Hashable | None = None,
#    6622     step: int | None = None,
#    6623 ) -> slice:
#    6624     """
#    6625     Compute the slice indexer for input labels and step.
#    6626
#    (...)
#    6660     slice(1, 3, None)
#    6661     """
# -> 6662     start_slice, end_slice = self.slice_locs(start, end, step=step)
#    6664     # return a slice
#    6665     if not is_scalar(start_slice):
#
# File c:\Users\ABHIJEET.BHAMBERE\Desktop\Resources\pandas_repo\.venv\Lib\site-packages\pandas\core\indexes\base.py:6879, in Index.slice_locs(self, start, end, step)
#    6877 start_slice = None
#    6878 if start is not None:
# -> 6879     start_slice = self.get_slice_bound(start, "left")
#    6880 if start_slice is None:
#    6881     start_slice = 0
#
# File c:\Users\ABHIJEET.BHAMBERE\Desktop\Resources\pandas_repo\.venv\Lib\site-packages\pandas\core\indexes\base.py:6812, in Index.get_slice_bound(self, label, side)
#    6810     slc = lib.maybe_booleans_to_slice(slc.view("u1"))
#    6811     if isinstance(slc, np.ndarray):
# -> 6812         raise KeyError(
#    6813             f"Cannot get {side} slice bound for non-unique "
#    6814             f"label: {repr(original_label)}"
#    6815         )
#    6817 if isinstance(slc, slice):
#    6818     if side == "left":
#
# KeyError: "Cannot get left slice bound for non-unique label: 'Casino Royale'"

# %% [markdown]
# ## Second Arguments to loc and iloc Accessors
# - The second value inside the square brackets targets the columns.
# - The `iloc` requires numeric positions for rows and columns.
# - The `loc` requires labels for rows and columns.

# %% [markdown]
# #### The art of getting to a specific value with at row-column intersection

# %%
bond = bond.sort_index()
bond.head()
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
bond.loc["Casino Royale","Actor"]
# Out:
# Film
# Casino Royale    Daniel Craig
# Casino Royale     David Niven
# Name: Actor, dtype: object

# %%
bond.loc["Quantum of Solace","Actor"]
bond.loc["Quantum of Solace","Director"]
bond.loc["Skyfall","Director"]
# Out:
# 'Sam Mendes'

# %% [markdown]
# ##### Selecting custom portion of the DataFrame -- involving multiple rows & columns

# %%
# Selecting from index A to B and fetch only Actor column
# If its a single column it'll be a series

bond.loc["Goldfinger":"Moonraker","Actor"]
# Out:
# Film
# Goldfinger            Sean Connery
# Licence to Kill     Timothy Dalton
# Live and Let Die       Roger Moore
# Moonraker              Roger Moore
# Name: Actor, dtype: object

# %%
# If more than one column is fetched , it'll be a dataframe

bond.loc["Goldfinger":"Moonraker",["Actor","Year"]]

bond.loc["Goldfinger":"Moonraker",["Actor","Box Office"]]
# Out:
#                            Actor  Box Office
# Film
# Goldfinger          Sean Connery       820.4
# Licence to Kill   Timothy Dalton       250.9
# Live and Let Die     Roger Moore       460.3
# Moonraker            Roger Moore       535.0

# %% [markdown]
# ## Overwrite Value in a DataFrame
# - Use the `iloc` or `loc` accessor on the **DataFrame** to target a value, then provide the equal sign and a new value.

# %% [markdown]
# ##  Overwrite Multiple Values in a DataFrame
# - The `replace` method replaces all occurrences of a **Series** value with another value (think of it like "Find and Replace").
# - To overwrite multiple values in a **DataFrame**, remember to use an accessor on the **DataFrame** itself.
# - Accessors like `loc` and `iloc` can accept Boolean Series. Use them to target the values to overwrite.

# %% [markdown]
# ## Rename Index Labels or Columns in a DataFrame
# - The `rename` method accepts a dictionary for either its `columns` or `index` parameters.
# - The dictionary keys represent the existing names and the values represent the new names.
# - We can replace all columns by overwriting the **DataFrame's** `columns` attribute.

# %% [markdown]
# ## Delete Rows or Columns from a DataFrame
# - The `drop` method deletes one or more rows/columns from a **DataFrame**.
# - Pass the `index` or `columns` parameters a list of the column names to remove.
# - The `pop` method removes and returns a single **Series** (it mutates the **DataFrame** in the process).
# - Python's `del` keyword also removes a single **Series**.

# %% [markdown]
# ## Create Random Sample with the sample Method
# - The `sample` method returns a specified one or more random rows from the **DataFrame**.
# - Customize the `axis` parameter to extract random columns.

# %% [markdown]
# ## The nsmallest and nlargest Methods
# - The `nlargest` method returns a specified number of rows with the largest values from a given column.
# - The `nsmallest` method returns rows with the smallest values from a given column.
# - The `nlargest` and `nsmallest` methods are more efficient than sorting the entire **DataFrame**.

# %% [markdown]
# ## Filtering with the where Method
# - Similar to square brackets or `loc`, the `where` method filters the original `DataFrame` with a Boolean Series.
# - Pandas will populate rows that do **not** match the criteria with `NaN` values.
# - Leaving in the `NaN` values can be advantageous for certain merge and visualization operations.

# %% [markdown]
# ## The apply Method with DataFrames
# - The `apply` method invokes a function on every column or every row in the **DataFrame**.
# - Pass the uninvoked function as the first argument to the `apply` method.
# - Pass the `axis` parameter an argument of `"columns"` to invoke the function on every row.
# - Pandas will pass in the row's values as a **Series** object. We can use accessors like `loc` and `iloc` to extract the column's values for that row.
