# %% [markdown]
# # DataFrames I

# %%
import pandas as pd

# %% [markdown]
# ## Methods and Attributes between Series and DataFrames
# - A **DataFrame** is a 2-dimensional table consisting of rows and columns.
# - Pandas uses a `NaN` designation for cells that have a missing value. It is short for "not a number". Most operations on `NaN` values will produce `NaN` values.
# - Like with a **Series**, Pandas assigns an index position/label to each **DataFrame** row.
# - The **DataFrame** and **Series** have common and exclusive methods/attributes.
# - The `hasnans` attribute exists only a **Series**. The `columns` attribute exists only on a **DataFrame**.
# - Some methods/attributes will return different types of data.
# - The `info` method returns a summary of the pandas object.

# %% [markdown]
# ### *Let's Go!!!!*

# %%
nba=pd.read_csv("nba.csv")
nba
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
# 591                NaN                 NaN      NaN    NaN     NaN
#
#            College      Salary
# 0        Villanova   4556983.0
# 1       Fenerbahce  18700000.0
# 2         Michigan   4094244.0
# 3      Elan Chalon  20616000.0
# ...

# %%
nba.head()
nba.tail()
# Out:
#                  Name                Team Position Height  Weight  \
# 587      Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588     Landry Shamet  Washington Wizards        G    6-4   190.0
# 589  Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590      Delon Wright  Washington Wizards        G    6-5   185.0
# 591               NaN                 NaN      NaN    NaN     NaN
#
#            College      Salary
# 587         Toledo   1719864.0
# 588  Wichita State  10250000.0
# 589    Real Madrid         NaN
# 590           Utah   8195122.0
# 591            NaN         NaN

# %%
nba.index
nba.values
# Out:
# array([['Saddiq Bey', 'Atlanta Hawks', 'F', ..., 215.0, 'Villanova',
#         4556983.0],
#        ['Bogdan Bogdanovic', 'Atlanta Hawks', 'G', ..., 225.0,
#         'Fenerbahce', 18700000.0],
#        ['Kobe Bufkin', 'Atlanta Hawks', 'G', ..., 195.0, 'Michigan',
#         4094244.0],
#        ...,
#        ['Tristan Vukcevic', 'Washington Wizards', 'F', ..., 220.0,
#         'Real Madrid', nan],
#        ['Delon Wright', 'Washington Wizards', 'G', ..., 185.0, 'Utah',
#         8195122.0],
#        [nan, nan, nan, ..., nan, nan, nan]], shape=(592, 7), dtype=object)

# %% [markdown]
# #### `shape` attribute returns a tuple with the DataFrame's dimensions in a **rows** x **columns** format <br>
# #### `size` returns the total no. of elements in the DataFrame ie the product of the total rows & columns in the dataset

# %%
print(nba.shape)
print(nba.size)
# Out:
# (592, 7)
# 4144

# %% [markdown]
# #### pandas uses an Index object to store all the columns in a database.
# #### The columns are also assigned an index position - starting at 0.... similar to a Series or List

# %%
nba.columns
# Out:
# Index(['Name', 'Team', 'Position', 'Height', 'Weight', 'College', 'Salary'], dtype='object')

# %% [markdown]
# #### `axes` attribute gives a list of ALL available axes -- horizontal(each of the columns) as well as vertical(rows)

# %%
nba.axes
# Out:
# [RangeIndex(start=0, stop=592, step=1),
#  Index(['Name', 'Team', 'Position', 'Height', 'Weight', 'College', 'Salary'], dtype='object')]

# %%
type(nba)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# #### `info` method gives an overview of the total null & non-null objects in a DataFrame alongwith column datatype & total memory usage of the DataFrame

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 592 entries, 0 to 591
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      591 non-null    object
#  1   Team      591 non-null    object
#  2   Position  584 non-null    object
#  3   Height    585 non-null    object
#  4   Weight    584 non-null    float64
#  5   College   578 non-null    object
#  6   Salary    488 non-null    float64
# dtypes: float64(2), object(5)
# memory usage: 32.5+ KB

# %% [markdown]
# #### `count` method also gives similar result but shows non-null counts only

# %%
nba.count()
# Out:
# Name        591
# Team        591
# Position    584
# Height      585
# Weight      584
# College     578
# Salary      488
# dtype: int64

# %% [markdown]
# #### `describe` method by default works only on numeric (int / float) dtypes

# %%
nba.describe()
# Out:
#            Weight        Salary
# count  584.000000  4.880000e+02
# mean   214.763699  9.218978e+06
# std     23.460612  1.131927e+07
# min    160.000000  5.088910e+05
# 25%    198.000000  1.980599e+06
# 50%    215.000000  4.018638e+06
# 75%    230.000000  1.169694e+07
# max    290.000000  5.191562e+07

# %% [markdown]
# ___
# ## Differences between Shared Methods
# - The `sum` method adds a **Series's** values.
# - On a **DataFrame**, the `sum` method defaults to adding the values by traversing the index (row values).
# - The `axis` parameter customizes the direction that we add across. Pass `"columns"` or `1` to add "across" the columns.

# %% [markdown]
# ### We can set any one of the DataFrame columns as the index

# %%
revenue = pd.read_csv("revenue.csv",index_col="Date")
revenue
# Out:
#          New York  Los Angeles  Miami
# Date
# 1/1/26        985          122    499
# 1/2/26        738          788    534
# 1/3/26         14           20    933
# 1/4/26        730          904    885
# 1/5/26        114           71    253
# 1/6/26        936          502    497
# 1/7/26        123          996    115
# 1/8/26        935          492    886
# 1/9/26        846          954    823
# 1/10/26        54          285    216

# %% [markdown]
# #### The `axis` parameter helps control the direction in which the `sum` method traverses -- either down a column (default) OR along a row

# %%
# Adds all non-NaN values across each column ie sums along the index for each of the column
revenue.sum()
revenue.sum(axis="index")
revenue.sum(axis=0)
# Out:
# New York       5475
# Los Angeles    5134
# Miami          5641
# dtype: int64

# %%
# Setting axis=1 dictates the sum method to add across each index ie. across the lenght of each row across all columns
revenue.sum(axis=1)
revenue.sum(axis="columns")
# Out:
# Date
# 1/1/26     1606
# 1/2/26     2060
# 1/3/26      967
# 1/4/26     2519
# 1/5/26      438
# 1/6/26     1935
# 1/7/26     1234
# 1/8/26     2313
# 1/9/26     2623
# 1/10/26     555
# dtype: int64

# %%
# We can sum this series to get a grand total
revenue.sum(axis="columns").sum()
# Out:
# np.int64(16250)

# %% [markdown]
# #### The ability to change the direction in which a method operates unlocks newer perspective
# In this example , keeping the default axis param (0 OR "index") we get total revenue for each of the cities, enabling a city-wise comparison of revenue.<br>
# Changing axis to 1 (or "columns") gives us a monthly sum of revenue, enabling a month-wise comparison of total revenue.<br>
# Both perspectives are important  as per the context or business requirement.

# %% [markdown]
# ## Select One Column from a DataFrame
# - We can use attribute syntax (`df.column_name`) to select a column from a **DataFrame**. The syntax will not work if the column name has spaces.
# - We can also use square bracket syntax (`df["column name"]`) which will work for any column name.
# - Pandas extracts a column from a **DataFrame** as a **Series**.
# - The **Series** is a view, so changes to the **Series** *will* affect the **DataFrame**.
# - Pandas will display a warning if you mutate the **Series**. Use the `copy` method to create a duplicate.

# %%
# This is one way of selecting a column & showing as a Series
nba.Name
# Out:
# 0             Saddiq Bey
# 1      Bogdan Bogdanovic
# 2            Kobe Bufkin
# 3           Clint Capela
# 4         Bruno Fernando
#              ...
# 587         Ryan Rollins
# 588        Landry Shamet
# 589     Tristan Vukcevic
# 590         Delon Wright
# 591                  NaN
# Name: Name, Length: 592, dtype: object

# %%
type(nba.Name)
# Out:
# pandas.core.series.Series

# %%
# This is another method of fetching a Series 
nba["Name"]
# Out:
# 0             Saddiq Bey
# 1      Bogdan Bogdanovic
# 2            Kobe Bufkin
# 3           Clint Capela
# 4         Bruno Fernando
#              ...
# 587         Ryan Rollins
# 588        Landry Shamet
# 589     Tristan Vukcevic
# 590         Delon Wright
# 591                  NaN
# Name: Name, Length: 592, dtype: object

# %% [markdown]
# #### NOTE that both methods give a View of the DataFrame -- so modifying it would modify to the original DataFrame

# %%
names = nba["Name"]
names.head()
# Out:
# 0           Saddiq Bey
# 1    Bogdan Bogdanovic
# 2          Kobe Bufkin
# 3         Clint Capela
# 4       Bruno Fernando
# Name: Name, dtype: object

# %%
names.iloc[0] = "This New Name"
names.head()
# Out:
# C:\Users\ABHIJEET.BHAMBERE\AppData\Local\Temp\ipykernel_27128\2025368477.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   names.iloc[0] = "This New Name"
# 0        This New Name
# 1    Bogdan Bogdanovic
# 2          Kobe Bufkin
# 3         Clint Capela
# 4       Bruno Fernando
# Name: Name, dtype: object

# %% [markdown]
# ##### But checking on original `nba` DataFrame we se that it also has been changed

# %%
nba.head()
# Out:
#                 Name           Team Position Height  Weight      College  \
# 0      This New Name  Atlanta Hawks        F    6-7   215.0    Villanova
# 1  Bogdan Bogdanovic  Atlanta Hawks        G    6-5   225.0   Fenerbahce
# 2        Kobe Bufkin  Atlanta Hawks        G    6-5   195.0     Michigan
# 3       Clint Capela  Atlanta Hawks        C   6-10   256.0  Elan Chalon
# 4     Bruno Fernando  Atlanta Hawks      F-C   6-10   240.0     Maryland
#
#        Salary
# 0   4556983.0
# 1  18700000.0
# 2   4094244.0
# 3  20616000.0
# 4   2581522.0

# %% [markdown]
# #### Avoid this by taking a `copy` of the required series so it is decoupled from the original DataFrame

# %%
nba = pd.read_csv("nba.csv")

# %%
names = nba["Name"].copy()
names.iloc[0] == "A New Name"
# Out:
# False

# %%
names.head()
# Out:
# 0           Saddiq Bey
# 1    Bogdan Bogdanovic
# 2          Kobe Bufkin
# 3         Clint Capela
# 4       Bruno Fernando
# Name: Name, dtype: object

# %% [markdown]
# #### As seen the original df remains unaffected & changes only apply to the copy

# %%
nba.head()
# Out:
#                 Name           Team Position Height  Weight      College  \
# 0         Saddiq Bey  Atlanta Hawks        F    6-7   215.0    Villanova
# 1  Bogdan Bogdanovic  Atlanta Hawks        G    6-5   225.0   Fenerbahce
# 2        Kobe Bufkin  Atlanta Hawks        G    6-5   195.0     Michigan
# 3       Clint Capela  Atlanta Hawks        C   6-10   256.0  Elan Chalon
# 4     Bruno Fernando  Atlanta Hawks      F-C   6-10   240.0     Maryland
#
#        Salary
# 0   4556983.0
# 1  18700000.0
# 2   4094244.0
# 3  20616000.0
# 4   2581522.0

# %% [markdown]
# ## Select Multiple Columns from a DataFrame
# - Use square brackets with a list of names to extract multiple **DataFrame** columns.
# - Pandas stores the result in a new **DataFrame** (a copy).

# %%
nba[["Name","Team"]]
nba[["Team","Name"]]
# Out:
#                    Team               Name
# 0         Atlanta Hawks         Saddiq Bey
# 1         Atlanta Hawks  Bogdan Bogdanovic
# 2         Atlanta Hawks        Kobe Bufkin
# 3         Atlanta Hawks       Clint Capela
# 4         Atlanta Hawks     Bruno Fernando
# ..                  ...                ...
# 587  Washington Wizards       Ryan Rollins
# 588  Washington Wizards      Landry Shamet
# 589  Washington Wizards   Tristan Vukcevic
# 590  Washington Wizards       Delon Wright
# 591                 NaN                NaN
#
# [592 rows x 2 columns]

# %%
select_columns = ["Name","Team","Salary"]
nba[select_columns].head()
# Out:
#                 Name           Team      Salary
# 0         Saddiq Bey  Atlanta Hawks   4556983.0
# 1  Bogdan Bogdanovic  Atlanta Hawks  18700000.0
# 2        Kobe Bufkin  Atlanta Hawks   4094244.0
# 3       Clint Capela  Atlanta Hawks  20616000.0
# 4     Bruno Fernando  Atlanta Hawks   2581522.0

# %% [markdown]
# ## Add New Column to DataFrame
# - Use square bracket extraction syntax with an equal sign to add a new **Series** to a **DataFrame**.
# - The `insert` method allows us to insert an element at a specific column index.
# - On the right-hand side, we can reference an existing **DataFrame** column and perform a broadcasting operation on it to create the new **Series**.

# %%
nba.shape
# Out:
# (592, 7)

# %% [markdown]
# #### Adding a column with one single value throughout

# %%
nba.insert(loc=3,column="Sport",value="Basketball")
nba.head()
# Out:
#                 Name           Team Position       Sport Height  Weight  \
# 0         Saddiq Bey  Atlanta Hawks        F  Basketball    6-7   215.0
# 1  Bogdan Bogdanovic  Atlanta Hawks        G  Basketball    6-5   225.0
# 2        Kobe Bufkin  Atlanta Hawks        G  Basketball    6-5   195.0
# 3       Clint Capela  Atlanta Hawks        C  Basketball   6-10   256.0
# 4     Bruno Fernando  Atlanta Hawks      F-C  Basketball   6-10   240.0
#
#        College      Salary
# 0    Villanova   4556983.0
# 1   Fenerbahce  18700000.0
# 2     Michigan   4094244.0
# 3  Elan Chalon  20616000.0
# 4     Maryland   2581522.0

# %% [markdown]
# #### Adding a column with a calculated value (dependent on value from another column)

# %%
nba["Salary"] * 2
nba["Salary doubled"] = nba["Salary"] * 2
nba.head()
# Out:
#                 Name           Team Position       Sport Height  Weight  \
# 0         Saddiq Bey  Atlanta Hawks        F  Basketball    6-7   215.0
# 1  Bogdan Bogdanovic  Atlanta Hawks        G  Basketball    6-5   225.0
# 2        Kobe Bufkin  Atlanta Hawks        G  Basketball    6-5   195.0
# 3       Clint Capela  Atlanta Hawks        C  Basketball   6-10   256.0
# 4     Bruno Fernando  Atlanta Hawks      F-C  Basketball   6-10   240.0
#
#        College      Salary  Salary doubled
# 0    Villanova   4556983.0       9113966.0
# 1   Fenerbahce  18700000.0      37400000.0
# 2     Michigan   4094244.0       8188488.0
# 3  Elan Chalon  20616000.0      41232000.0
# 4     Maryland   2581522.0       5163044.0

# %%
nba.tail()
# Out:
#                  Name                Team Position       Sport Height  Weight  \
# 587      Ryan Rollins  Washington Wizards        G  Basketball    6-3   180.0
# 588     Landry Shamet  Washington Wizards        G  Basketball    6-4   190.0
# 589  Tristan Vukcevic  Washington Wizards        F  Basketball   6-10   220.0
# 590      Delon Wright  Washington Wizards        G  Basketball    6-5   185.0
# 591               NaN                 NaN      NaN  Basketball    NaN     NaN
#
#            College      Salary  Salary doubled
# 587         Toledo   1719864.0       3439728.0
# 588  Wichita State  10250000.0      20500000.0
# 589    Real Madrid         NaN             NaN
# 590           Utah   8195122.0      16390244.0
# 591            NaN         NaN             NaN

# %%
nba["Salarat post decutn"]=nba["Salary"]-(nba["Salary"]*0.15)
nba.head()
# Out:
#                 Name           Team Position       Sport Height  Weight  \
# 0         Saddiq Bey  Atlanta Hawks        F  Basketball    6-7   215.0
# 1  Bogdan Bogdanovic  Atlanta Hawks        G  Basketball    6-5   225.0
# 2        Kobe Bufkin  Atlanta Hawks        G  Basketball    6-5   195.0
# 3       Clint Capela  Atlanta Hawks        C  Basketball   6-10   256.0
# 4     Bruno Fernando  Atlanta Hawks      F-C  Basketball   6-10   240.0
#
#        College      Salary  Salary doubled  Salarat post decutn
# 0    Villanova   4556983.0       9113966.0           3873435.55
# 1   Fenerbahce  18700000.0      37400000.0          15895000.00
# 2     Michigan   4094244.0       8188488.0           3480107.40
# 3  Elan Chalon  20616000.0      41232000.0          17523600.00
# 4     Maryland   2581522.0       5163044.0           2194293.70

# %% [markdown]
# #### Adding a List as a New column to the DataFrame
# Creating a sample List that match no. of rows of nba dataframe

# %%
import numpy as np

def generate_nos(length,minval,maxval):
    '''Generates a list of random no.s. Mention min & max(inclusive) of the range with intervals(length)'''
    return np.random.randint(minval,(maxval+1),size=length).tolist()

# %%
# Generating a new List that match the length of the DataFrame (rows)
newlist = generate_nos(1000,1,1000)
newlist1=newlist[:592]

# %%
len(newlist1)
# Out:
# 592

# %%
# Adding the List as a new column to the DataFrame
nba.insert(loc=1,column="PlayerID",value=newlist1)
nba.head()
# Out:
#                 Name  PlayerID           Team Position       Sport Height  \
# 0         Saddiq Bey       441  Atlanta Hawks        F  Basketball    6-7
# 1  Bogdan Bogdanovic       694  Atlanta Hawks        G  Basketball    6-5
# 2        Kobe Bufkin       979  Atlanta Hawks        G  Basketball    6-5
# 3       Clint Capela       114  Atlanta Hawks        C  Basketball   6-10
# 4     Bruno Fernando       404  Atlanta Hawks      F-C  Basketball   6-10
#
#    Weight      College      Salary  Salary doubled  Salarat post decutn
# 0   215.0    Villanova   4556983.0       9113966.0           3873435.55
# 1   225.0   Fenerbahce  18700000.0      37400000.0          15895000.00
# 2   195.0     Michigan   4094244.0       8188488.0           3480107.40
# 3   256.0  Elan Chalon  20616000.0      41232000.0          17523600.00
# 4   240.0     Maryland   2581522.0       5163044.0           2194293.70

# %%
nba.tail()
# Out:
#                  Name  PlayerID                Team Position       Sport  \
# 587      Ryan Rollins       278  Washington Wizards        G  Basketball
# 588     Landry Shamet       551  Washington Wizards        G  Basketball
# 589  Tristan Vukcevic       827  Washington Wizards        F  Basketball
# 590      Delon Wright       985  Washington Wizards        G  Basketball
# 591               NaN       159                 NaN      NaN  Basketball
#
#     Height  Weight        College      Salary  Salary doubled  \
# 587    6-3   180.0         Toledo   1719864.0       3439728.0
# 588    6-4   190.0  Wichita State  10250000.0      20500000.0
# 589   6-10   220.0    Real Madrid         NaN             NaN
# 590    6-5   185.0           Utah   8195122.0      16390244.0
# 591    NaN     NaN            NaN         NaN             NaN
#
#      Salarat post decutn
# 587            1461884.4
# 588            8712500.0
# 589                  NaN
# 590            6965853.7
# ...

# %% [markdown]
# ## A Review of the value_counts Method
# - The `value_counts` method counts the number of times that each unique value occurs in a **Series**.

# %%
nba["Team"].value_counts(ascending=True)
# Out:
# Team
# New Orleans Pelicans      16
# Brooklyn Nets             17
# Portland Trail Blazers    17
# Golden State Warriors     17
# Orlando Magic             18
# Sacramento Kings          18
# Boston Celtics            18
# Atlanta Hawks             18
# Los Angeles Clippers      19
# Los Angeles Lakers        19
# Detroit Pistons           19
# Minnesota Timberwolves    19
# Cleveland Cavaliers       19
# Chicago Bulls             19
# Charlotte Hornets         20
# Houston Rockets           20
# Phoenix Suns              20
# San Antonio Spurs         20
# Utah Jazz                 21
# Toronto Raptors           21
# Indiana Pacers            21
# Philadelphia 76ers        21
# New York Knicks           21
# Oklahoma City Thunder     21
# Washington Wizards        21
# Miami Heat                22
# Denver Nuggets            22
# Memphis Grizzlies         22
# Milwaukee Bucks           22
# Dallas Mavericks          23
# Name: count, dtype: int64

# %%
nba["Team"].value_counts().sort_index().plot(kind='bar',figsize=(18,4))
# Out:
# <Axes: xlabel='Team'>

# %% [markdown]
# #### Exploring the dataset for some insights:
# For instance, we can see which position occurrs the most in the dataset:

# %%
(nba["Position"].value_counts(ascending=True,normalize=True)*100).plot(kind="barh")
# Out:
# <Axes: ylabel='Position'>

# %% [markdown]
# Or we can see the salary:

# %%
nba["Salary"].value_counts()
# Out:
# Salary
# 559782.0      59
# 1119563.0     27
# 3196448.0     13
# 2019706.0      9
# 1719864.0      8
#               ..
# 2581522.0      1
# 20616000.0     1
# 4094244.0      1
# 18700000.0     1
# 4556983.0      1
# Name: count, Length: 298, dtype: int64

# %% [markdown]
# ## Drop Rows with Missing Values
# - Pandas uses a `NaN` designation for cells that have a missing value.
# - The `dropna` method deletes rows with missing values. Its default behavior is to remove a row if it has *any* missing values.
# - Pass the `how` parameter an argument of "all" to delete rows where all the values are `NaN`.
# - The `subset` parameters customizes/limits the columns that pandas will use to drop rows with missing values.

# %% [markdown]
# #### One of THE MOST useful methods in pandas when handling missing or NaN values in a dataset.

# %%
nba = pd.read_csv("nba.csv")
nba
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
# 591                NaN                 NaN      NaN    NaN     NaN
#
#            College      Salary
# 0        Villanova   4556983.0
# 1       Fenerbahce  18700000.0
# 2         Michigan   4094244.0
# 3      Elan Chalon  20616000.0
# ...

# %% [markdown]
# #### Use of the `dropna` method depends on the use case -- either we might be better off removing a row **entirely** if even one of its column values are NaN /missing.
# #### OR it could be the case that we might want to retain a row that has NaN but its other column values could be useful for other aspects of our analysis.

# %%
# This removes rows with even a single NaN column value
nba.dropna()
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 585     Eugene Omoruyi  Washington Wizards        F    6-6   235.0
# 586       Jordan Poole  Washington Wizards        G    6-4   194.0
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
#
#            College      Salary
# 0        Villanova   4556983.0
# 1       Fenerbahce  18700000.0
# 2         Michigan   4094244.0
# 3      Elan Chalon  20616000.0
# ...

# %%
# Notice only the last row is removed -- one that had all column values missing. 
nba.dropna(how="all")
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 586       Jordan Poole  Washington Wizards        G    6-4   194.0
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
#
#            College      Salary
# 0        Villanova   4556983.0
# 1       Fenerbahce  18700000.0
# 2         Michigan   4094244.0
# 3      Elan Chalon  20616000.0
# ...

# %% [markdown]
# #### The `subset` parameter allows for a conditional dropping of rows. It tells the `dropna` func to look for NaN vlaues in a particular column(s) in a DataFrame AND only then drop the row.

# %%
# Drop entire row only if College column has NaN value
nba.dropna(subset=["College"])
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 586       Jordan Poole  Washington Wizards        G    6-4   194.0
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
#
#            College      Salary
# 0        Villanova   4556983.0
# 1       Fenerbahce  18700000.0
# 2         Michigan   4094244.0
# 3      Elan Chalon  20616000.0
# ...

# %%
# Drop entire row only if EITHER College OR Salary columns have NaN values
nba.dropna(subset=["College","Salary"])
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 585     Eugene Omoruyi  Washington Wizards        F    6-6   235.0
# 586       Jordan Poole  Washington Wizards        G    6-4   194.0
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
#
#            College      Salary
# 0        Villanova   4556983.0
# 1       Fenerbahce  18700000.0
# 2         Michigan   4094244.0
# 3      Elan Chalon  20616000.0
# ...

# %% [markdown]
# ## Fill in Missing Values with the fillna Method
# - The `fillna` method replaces missing `NaN` values with its argument.
# - The `fillna` method is available on both **DataFrames** and **Series**.
# - An extracted **Series** is a view on the original **DataFrame**, but the `fillna` method returns a copy.

# %% [markdown]
# For example, we might want to replace the NaN with 0.0 in the Salary column instead of deleting the row

# %%
nba["Salary"]=nba["Salary"].fillna(0.0,)
nba.iloc[60:75]
# Out:
#                Name               Team Position Height  Weight        College  \
# 60     Theo Maledon  Charlotte Hornets        G    6-5   175.0          Asvel
# 61      Cody Martin  Charlotte Hornets        F    6-6   205.0         Nevada
# 62   Bryce McGowens  Charlotte Hornets        G    6-6   175.0       Nebraska
# 63   Brandon Miller  Charlotte Hornets        F    6-9   200.0        Alabama
# 64      James Nnaji  Charlotte Hornets        F   6-11   250.0   FC Barcelona
# 65  Frank Ntilikina  Charlotte Hornets        G    6-4   200.0  Strasbourg IG
# 66  Kelly Oubre Jr.  Charlotte Hornets      F-G    6-6   203.0         Kansas
# 67    Nick Richards  Charlotte Hornets        C    7-0   245.0       Kentucky
# 68     Terry Rozier  Charlotte Hornets        G    6-1   190.0     Louisville
# 69   Nick Smith Jr.  Charlotte Hornets        G    6-5   185.0       Arkansas
# 70          JT Thor  Charlotte Hornets        F    6-9   203.0         Auburn
# ...

# %% [markdown]
# #### The `inplace` parameter can be used for funcs/ methods that present output as copy of thre original DataFrame
# Pass `inplace = True` while applying the method

# %%
nba["College"]=nba["College"].fillna(value="No Info Avlble")
nba
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
# 591                NaN                 NaN      NaN    NaN     NaN
#
#             College      Salary
# 0         Villanova   4556983.0
# 1        Fenerbahce  18700000.0
# 2          Michigan   4094244.0
# ...

# %% [markdown]
# #### It can be observed there's quite a few Player records where College information is not available

# %%
nba["College"].value_counts()
# Out:
# College
# Kentucky               29
# Duke                   25
# UCLA                   15
# No Info Avlble         14
# Kansas                 12
#                        ..
# Wisconsin-Milwaukee     1
# Winthrop                1
# Olimpia Milano          1
# Bucknell                1
# Toledo                  1
# Name: count, Length: 183, dtype: int64

# %% [markdown]
# ## The astype Method I
# - The `astype` method converts a **Series's** values to a specified type.
# - Pass in the specified type as either a string or the core Python data type.
# - Pandas cannot convert `NaN` values to numeric types, so we need to eliminate/replace them before we perform the conversion.
# - The `dtypes` attribute returns a **Series** with the **DataFrame's** columns and their types.

# %%
# Checking Salary DType before conversion
nba.dtypes
# Note that it is float64
# Out:
# Name         object
# Team         object
# Position     object
# Height       object
# Weight      float64
# College      object
# Salary      float64
# dtype: object

# %%
# Now converting Salary DType to integer
nba["Salary"]=nba["Salary"].astype("int")

# %%
#Note that its now changed to integer
nba.dtypes
# Out:
# Name         object
# Team         object
# Position     object
# Height       object
# Weight      float64
# College      object
# Salary        int64
# dtype: object

# %% [markdown]
# #### Trying something different! Piping the `fillna()` and `astype()` methods in the same query to minimize LOC & get same output

# %%
nba["Weight"]=nba["Weight"].fillna(0).astype(int)
nba.dtypes
# Out:
# Name        object
# Team        object
# Position    object
# Height      object
# Weight       int64
# College     object
# Salary       int64
# dtype: object

# %%
nba.head()
# Out:
#                 Name           Team Position Height  Weight      College  \
# 0         Saddiq Bey  Atlanta Hawks        F    6-7     215    Villanova
# 1  Bogdan Bogdanovic  Atlanta Hawks        G    6-5     225   Fenerbahce
# 2        Kobe Bufkin  Atlanta Hawks        G    6-5     195     Michigan
# 3       Clint Capela  Atlanta Hawks        C   6-10     256  Elan Chalon
# 4     Bruno Fernando  Atlanta Hawks      F-C   6-10     240     Maryland
#
#      Salary
# 0   4556983
# 1  18700000
# 2   4094244
# 3  20616000
# 4   2581522

# %% [markdown]
# ## The astype Method II
# - The `category` type is ideal for columns with a limited number of unique values.
# - The `nunique` method will return a **Series** with the number of unique values in each column.
# - With categories, pandas does not create a separate value in memory for each "cell". Rather, the cells point to a single copy for each unique value.
# #### This is very useful for large DataFrames

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 592 entries, 0 to 591
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      591 non-null    object
#  1   Team      591 non-null    object
#  2   Position  584 non-null    object
#  3   Height    585 non-null    object
#  4   Weight    592 non-null    int64
#  5   College   592 non-null    object
#  6   Salary    592 non-null    int64
# dtypes: int64(2), object(5)
# memory usage: 32.5+ KB

# %%
nba.nunique()
# We see that Team and Position can be converted into Category
# Out:
# Name        591
# Team         30
# Position      7
# Height       20
# Weight       94
# College     183
# Salary      299
# dtype: int64

# %% [markdown]
# #### Multiple columns can be converted at once as `Category`

# %%
nba[["Team","Position"]]=nba[["Team","Position"]].astype("category")

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 592 entries, 0 to 591
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      591 non-null    object
#  1   Team      591 non-null    category
#  2   Position  584 non-null    category
#  3   Height    585 non-null    object
#  4   Weight    592 non-null    int64
#  5   College   592 non-null    object
#  6   Salary    592 non-null    int64
# dtypes: category(2), int64(2), object(3)
# memory usage: 26.0+ KB

# %% [markdown]
# ## Sort a DataFrame with the sort_values Method I
# - The `sort_values` method sorts a **DataFrame** by the values in one or more columns. The default sort is an ascending one (alphabetical for strings).
# - The first parameter (`by`) expects the column(s) to sort by.
# - If sorting by a single column, pass a string with its name.
# - The `ascending` parameter customizes the sort order.
# - The `na_position` parameter customizes where pandas places `NaN` values.

# %%
# Creating a new nba dataframe:
newnba = pd.read_csv("nba.csv")
newnba.sort_values(by="Salary")
newnba.sort_values(by="Salary",na_position='first')
newnba.sort_values(by="Salary",na_position='first',ascending=False)
# Out:
#                     Name                Team Position Height  Weight  \
# 23         Blake Griffin      Boston Celtics        F    6-9   250.0
# 26     Mfiondu Kabengele      Boston Celtics        C   6-10   250.0
# 28        Svi Mykhailiuk      Boston Celtics      G-F    6-7   205.0
# 35   Robert Williams III      Boston Celtics      C-F    6-9   237.0
# 39           Nic Claxton       Brooklyn Nets        C   6-11   215.0
# ..                   ...                 ...      ...    ...     ...
# 572         Jared Butler  Washington Wizards        G    6-3   193.0
# 31            Jay Scrubb      Boston Celtics        G    6-5   220.0
# 22            JD Davison      Boston Celtics        G    6-1   195.0
# 555          Joey Hauser           Utah Jazz        F    6-9   230.0
# 5          Trent Forrest       Atlanta Hawks        G    6-4   210.0
#
#             College    Salary
# 23         Oklahoma       NaN
# 26    Florida State       NaN
# 28           Kansas       NaN
# ...

# %% [markdown]
# ## Sort a DataFrame with the sort_values Method II
# - To sort by multiple columns, pass the `by` parameter a list of column names. Pandas will sort in the specified column order (first to last).
# - Pass the `ascending` parameter a Boolean to sort all columns in a consistent order (all ascending or all descending).
# - Pass `ascending` a list to customize the sort order *per* column. The `ascending` list length must match the `by` list.

# %% [markdown]
# #### Passing multiple columns in `sort_values` is best illustrated when one or more columns have repeat values. As List being an ordered collection, the dataframe is sorted by the order of column names mentioned in the list.

# %%
newnba.sort_values(by=["Team","Name"])
# Notice college column is sorted first & then the team column
newnba.sort_values(by=["College","Team"])
# Out:
#                 Name                   Team Position Height  Weight  College  \
# 22        JD Davison         Boston Celtics        G    6-1   195.0  Alabama
# 40      Noah Clowney          Brooklyn Nets        F   6-10   210.0  Alabama
# 63    Brandon Miller      Charlotte Hornets        F    6-9   200.0  Alabama
# 177   JaMychal Green  Golden State Warriors      F-C    6-9   227.0  Alabama
# 361    Herbert Jones   New Orleans Pelicans        F    6-7   206.0  Alabama
# ..               ...                    ...      ...    ...     ...      ...
# 381    Jaylen Martin        New York Knicks        G    6-6   216.0      NaN
# 508  Dominick Barlow      San Antonio Spurs        F    6-9   215.0      NaN
# 541     Kevin Obanor        Toronto Raptors      NaN    6-8   235.0      NaN
# 564     Nick Ongenda              Utah Jazz      NaN    NaN     NaN      NaN
# 591              NaN                    NaN      NaN    NaN     NaN      NaN
#
#          Salary
# 22     559782.0
# ...

# %% [markdown]
# #### Each sorting within the list of sorting can also be controlled by passing a list of Booleans (true/false) into the `ascending` parameter

# %%
newnba.sort_values(by=["College","Team"],ascending=[True,False])
# Notice the college column is sprted in ascending since its assigned parameter for ascending is True
# while the teams are sorted in descending since its assigned False for the ascending parameter
# Out:
#                 Name                   Team Position Height  Weight  College  \
# 568    Collin Sexton              Utah Jazz        G    6-2   190.0  Alabama
# 493       Keon Ellis       Sacramento Kings        G    6-3   175.0  Alabama
# 361    Herbert Jones   New Orleans Pelicans        F    6-7   206.0  Alabama
# 362   Kira Lewis Jr.   New Orleans Pelicans        G    6-1   170.0  Alabama
# 177   JaMychal Green  Golden State Warriors      F-C    6-9   227.0  Alabama
# ..               ...                    ...      ...    ...     ...      ...
# 138  Armaan Franklin         Denver Nuggets      NaN    NaN     NaN      NaN
# 129    Jordan Walker       Dallas Mavericks      NaN    NaN     NaN      NaN
# 74     Onuralp Bitim          Chicago Bulls        F    6-6   215.0      NaN
# 15      Miles Norris          Atlanta Hawks      NaN    NaN     NaN      NaN
# 591              NaN                    NaN      NaN    NaN     NaN      NaN
#
#          Salary
# 568  17325000.0
# ...

# %%
# sorting positions in ascending and salaries by descending
newnba.sort_values(by=["Position","Salary"],ascending=[True,False],inplace=True)

# %%
newnba
# Out:
#               Name                    Team Position Height  Weight  \
# 145   Nikola Jokic          Denver Nuggets        C   6-11   284.0
# 344    Rudy Gobert  Minnesota Timberwolves        C    7-1   258.0
# 453  Deandre Ayton            Phoenix Suns        C    7-0   250.0
# 329    Brook Lopez         Milwaukee Bucks        C    7-1   282.0
# 3     Clint Capela           Atlanta Hawks        C   6-10   256.0
# ..             ...                     ...      ...    ...     ...
# 299  Caleb Daniels              Miami Heat      NaN    NaN     NaN
# 541   Kevin Obanor         Toronto Raptors      NaN    6-8   235.0
# 564   Nick Ongenda               Utah Jazz      NaN    NaN     NaN
# 15    Miles Norris           Atlanta Hawks      NaN    NaN     NaN
# 591            NaN                     NaN      NaN    NaN     NaN
#
#          College      Salary
# 145  Mega Basket  47607350.0
# 344       Cholet  41000000.0
# 453      Arizona  32459438.0
# 329     Stanford  25000000.0
# ...

# %% [markdown]
# ## Sort a DataFrame by its Index
# - The `sort_index` method sorts the **DataFrame** by its index positions/labels.

# %% [markdown]
# #### This method will be more useful in case of custom index labels or nested indexes

# %%
newnba
# Out:
#               Name                    Team Position Height  Weight  \
# 145   Nikola Jokic          Denver Nuggets        C   6-11   284.0
# 344    Rudy Gobert  Minnesota Timberwolves        C    7-1   258.0
# 453  Deandre Ayton            Phoenix Suns        C    7-0   250.0
# 329    Brook Lopez         Milwaukee Bucks        C    7-1   282.0
# 3     Clint Capela           Atlanta Hawks        C   6-10   256.0
# ..             ...                     ...      ...    ...     ...
# 299  Caleb Daniels              Miami Heat      NaN    NaN     NaN
# 541   Kevin Obanor         Toronto Raptors      NaN    6-8   235.0
# 564   Nick Ongenda               Utah Jazz      NaN    NaN     NaN
# 15    Miles Norris           Atlanta Hawks      NaN    NaN     NaN
# 591            NaN                     NaN      NaN    NaN     NaN
#
#          College      Salary
# 145  Mega Basket  47607350.0
# 344       Cholet  41000000.0
# 453      Arizona  32459438.0
# 329     Stanford  25000000.0
# ...

# %%
newnba.sort_index()
# Thre are few similar parameters
newnba.sort_index(ascending=False)
newnba.sort_index(ascending=False,inplace=True)
newnba
# Out:
#                   Name                Team Position Height  Weight  \
# 591                NaN                 NaN      NaN    NaN     NaN
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# ..                 ...                 ...      ...    ...     ...
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
#
#            College      Salary
# 591            NaN         NaN
# 590           Utah   8195122.0
# 589    Real Madrid         NaN
# 588  Wichita State  10250000.0
# ...

# %% [markdown]
# ## Rank Values with the rank Method
# - The `rank` method assigns a numeric ranking to each **Series** value.
# - Pandas will assign the same rank to equal values and create a "gap" in the dataset for the ranks.

# %%
nba=pd.read_csv("nba.csv").dropna(how="all")
# Handling NaNs in Salary column 
nba["Salary"] = nba["Salary"].fillna(0).astype(int)
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 591 entries, 0 to 590
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      591 non-null    object
#  1   Team      591 non-null    object
#  2   Position  584 non-null    object
#  3   Height    585 non-null    object
#  4   Weight    584 non-null    float64
#  5   College   578 non-null    object
#  6   Salary    591 non-null    int64
# dtypes: float64(1), int64(1), object(5)
# memory usage: 36.9+ KB

# %% [markdown]
# #### pandas `rank` func is similar to SQL -- both leave a gap in rank when there is a tie. If 2nd & 3d values are a tie, it'll be assgined ranks as 1,2,2,4 etc

# %%
# Introducing a new column in the DataFrame
nba["SalaryRank"] = nba["Salary"].rank(ascending=False).astype(int)

# %%
nba.sort_values(by=["Salary"],ascending=False)
# Out:
#                     Name                   Team Position Height  Weight  \
# 175        Stephen Curry  Golden State Warriors        G    6-2   185.0
# 461         Kevin Durant           Phoenix Suns        F   6-10   240.0
# 145         Nikola Jokic         Denver Nuggets        C   6-11   284.0
# 436          Joel Embiid     Philadelphia 76ers      C-F    7-0   280.0
# 261         LeBron James     Los Angeles Lakers        F    6-9   250.0
# ..                   ...                    ...      ...    ...     ...
# 547       Gary Trent Jr.        Toronto Raptors      G-F    6-5   209.0
# 23         Blake Griffin         Boston Celtics        F    6-9   250.0
# 26     Mfiondu Kabengele         Boston Celtics        C   6-10   250.0
# 28        Svi Mykhailiuk         Boston Celtics      G-F    6-7   205.0
# 35   Robert Williams III         Boston Celtics      C-F    6-9   237.0
#
#                           College    Salary  SalaryRank
# ...

# %%
# Applying a dense rank to assign different ranks to ties
nba["SalaryRank1"]=nba["Salary"].rank(ascending=False,method='dense').astype(int)
nba.sort_values(by=["SalaryRank1"],ascending=False)
# Out:
#                   Name                    Team Position Height  Weight  \
# 350  Wendell Moore Jr.  Minnesota Timberwolves        G    6-5   215.0
# 351      Jaylen Nowell  Minnesota Timberwolves        G    6-4   201.0
# 353      Austin Rivers  Minnesota Timberwolves        G    6-4   200.0
# 354          Matt Ryan  Minnesota Timberwolves        F    6-6   215.0
# 356      Jose Alvarado    New Orleans Pelicans        G    6-0   179.0
# ..                 ...                     ...      ...    ...     ...
# 261       LeBron James      Los Angeles Lakers        F    6-9   250.0
# 436        Joel Embiid      Philadelphia 76ers      C-F    7-0   280.0
# 145       Nikola Jokic          Denver Nuggets        C   6-11   284.0
# 461       Kevin Durant            Phoenix Suns        F   6-10   240.0
# 175      Stephen Curry   Golden State Warriors        G    6-2   185.0
#
#                           College    Salary  SalaryRank  SalaryRank1
# ...
