# %% [markdown]
# # Working with Text Data

# %%
import pandas as pd

# %% [markdown]
# ## This Module's Dataset
# - This module's dataset (`chicago.csv`) is a collection of public sector employees in the city of Chicago.
# - Each row inclues the employee's name, position, department, and salary.

# %%
chicago = pd.read_csv("chicago.csv").dropna(how="all")
chicago["Department"] = chicago["Department"].astype("category")
chicago.head()
# Out:
#                   Name            Position Title        Department  \
# 0      AARON,  ELVIA J          WATER RATE TAKER       WATER MGMNT
# 1    AARON,  JEFFERY M            POLICE OFFICER            POLICE
# 2       AARON,  KARINA            POLICE OFFICER            POLICE
# 3  AARON,  KIMBERLEI R  CHIEF CONTRACT EXPEDITER  GENERAL SERVICES
# 4  ABAD JR,  VICENTE M         CIVIL ENGINEER IV       WATER MGMNT
#
#   Employee Annual Salary
# 0              $90744.00
# 1              $84450.00
# 2              $84450.00
# 3              $89880.00
# 4             $106836.00

# %%
# Inspecting the dataset
chicago.shape

chicago.nunique()

chicago.info()
# chicago.value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32062 entries, 0 to 32061
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Name                    32062 non-null  object
#  1   Position Title          32062 non-null  object
#  2   Department              32062 non-null  category
#  3   Employee Annual Salary  32062 non-null  object
# dtypes: category(1), object(3)
# memory usage: 1.0+ MB

# %%
chicago["Position Title"].value_counts()
chicago["Position Title"].nunique()
# Out:
# 1093

# %% [markdown]
# ## Common String Methods
# - A **Series** has a special `str` attribute that exposes an object with string methods.
# - Access the `str` attribute, then invoke the string method on the nested object.
# - Most method names will match their Python method equivalents (`upper`, `lower`, `title`, etc).

# %%
chicago.head()
# Out:
#                   Name            Position Title        Department  \
# 0      AARON,  ELVIA J          WATER RATE TAKER       WATER MGMNT
# 1    AARON,  JEFFERY M            POLICE OFFICER            POLICE
# 2       AARON,  KARINA            POLICE OFFICER            POLICE
# 3  AARON,  KIMBERLEI R  CHIEF CONTRACT EXPEDITER  GENERAL SERVICES
# 4  ABAD JR,  VICENTE M         CIVIL ENGINEER IV       WATER MGMNT
#
#   Employee Annual Salary
# 0              $90744.00
# 1              $84450.00
# 2              $84450.00
# 3              $89880.00
# 4             $106836.00

# %%
astr = "the quick brown fox"
astr.title()
astr.capitalize()
# Out:
# 'The quick brown fox'

# %% [markdown]
# #### We use the `.str` accessor to apply string formatting methods to a series

# %%
format_change = chicago["Name"].str.title()
chicago.insert(loc=1,column="Formatted Name",value=format_change)
chicago.head()
# Out:
#                   Name       Formatted Name            Position Title  \
# 0      AARON,  ELVIA J      Aaron,  Elvia J          WATER RATE TAKER
# 1    AARON,  JEFFERY M    Aaron,  Jeffery M            POLICE OFFICER
# 2       AARON,  KARINA       Aaron,  Karina            POLICE OFFICER
# 3  AARON,  KIMBERLEI R  Aaron,  Kimberlei R  CHIEF CONTRACT EXPEDITER
# 4  ABAD JR,  VICENTE M  Abad Jr,  Vicente M         CIVIL ENGINEER IV
#
#          Department Employee Annual Salary
# 0       WATER MGMNT              $90744.00
# 1            POLICE              $84450.00
# 2            POLICE              $84450.00
# 3  GENERAL SERVICES              $89880.00
# 4       WATER MGMNT             $106836.00

# %% [markdown]
# #### Multiple `str` methods can be accessed by method chaining as shown below :

# %%
# Replacing string parts
chicago["Department"]
# changing 'MGMNT' to "Management"
chicago["Department"].str.replace("MGMNT","MANAGEMENT").str.title()
chicago["Department"].str.cap
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 5
#       3 # changing 'MGMNT' to "Management"
#       4 chicago["Department"].str.replace("MGMNT","MANAGEMENT").str.title()
# ----> 5 chicago["Department"].str.cap
#
# AttributeError: 'StringMethods' object has no attribute 'cap'

# %%
# Another way of replacing given names:
chicago["Department"].value_counts()
# Out:
# Department
# POLICE                   12618
# FIRE                      4796
# STREETS & SAN             2152
# OEMC                      1982
# WATER MGMNT               1840
# AVIATION                  1521
# TRANSPORTN                1073
# PUBLIC LIBRARY             961
# GENERAL SERVICES           930
# FAMILY & SUPPORT           654
# FINANCE                    577
# HEALTH                     529
# LAW                        414
# CITY COUNCIL               396
# BUILDINGS                  262
# COMMUNITY DEVELOPMENT      208
# BUSINESS AFFAIRS           161
# BOARD OF ELECTION          117
# DoIT                       102
# CITY CLERK                  94
# MAYOR'S OFFICE              86
# PROCUREMENT                 83
# IPRA                        82
# CULTURAL AFFAIRS            74
# HUMAN RESOURCES             70
# ANIMAL CONTRL               67
# INSPECTOR GEN               57
# ADMIN HEARNG                39
# BUDGET & MGMT               39
# DISABILITIES                28
# TREASURER                   22
# HUMAN RELATIONS             16
# BOARD OF ETHICS              9
# POLICE BOARD                 2
# LICENSE APPL COMM            1
# Name: count, dtype: int64

# %%
# Extracting the Dept Names into a new list
proper_depts = chicago["Department"].to_list()

# declaring a new blank list -- this one will be filled with the renamed names & later inserted into the DataFrame
new_modified_names = []

# code will look for these key maps in each value of the extracted list
check_keywords = {"MGMNT":"MANAGEMENT", "MGMT":"MANAGEMENT" , "SAN":"Sanitary" , "DoIT": "Dept Of IT" ,"GEN":"GENERAL","CONTRL":"Control","COMM":"Community"}

# %%
new_modified_names = []
check_keywords = {
    "MGMNT":"MANAGEMENT", "MGMT":"MANAGEMENT" , "SAN":"Sanitary" , "DoIT": "Dept Of IT" ,"GEN":"GENERAL","CONTRL":"Control","COMM":"Community"
}

# %%
for record in proper_depts:
    new_rec = record
    for existing,newstring in check_keywords.items():
        new_rec = new_rec.replace(existing,newstring)
    new_modified_names.append(new_rec)
print(new_modified_names)
# Out:
# ['WATER MANAGEMENT', 'POLICE', 'POLICE', 'GENERALERAL SERVICES', 'WATER MANAGEMENT', 'CITY COUNCIL', 'STREETS & Sanitary', 'OEMC', 'CITY COUNCIL', 'AVIATION', 'FIRE', 'POLICE', 'FAMILY & SUPPORT', 'POLICE', 'IPRA', 'POLICE', 'POLICE', 'FIRE', 'POLICE', 'FIRE', 'WATER MANAGEMENT', 'FIRE', 'FIRE', 'OEMC', 'GENERALERAL SERVICES', 'WATER MANAGEMENT', 'STREETS & Sanitary', 'FAMILY & SUPPORT', 'POLICE', 'FIRE', 'STREETS & Sanitary', 'PUBLIC LIBRARY', 'POLICE', 'FAMILY & SUPPORT', 'WATER MANAGEMENT', 'BUSINESS AFFAIRS', 'POLICE', 'OEMC', 'STREETS & Sanitary', 'POLICE', 'FIRE', 'STREETS & Sanitary', 'FIRE', 'WATER MANAGEMENT', 'STREETS & Sanitary', 'TRANSPORTN', 'HEALTH', 'FAMILY & SUPPORT', 'FIRE', 'POLICE', 'AVIATION', 'HEALTH', 'POLICE', 'WATER MANAGEMENT', 'POLICE', 'WATER MANAGEMENT', 'POLICE', 'AVIATION', 'POLICE', 'POLICE', 'STREETS & Sanitary', 'STREETS & Sanitary', "MAYOR'S OFFICE", 'POLICE', 'POLICE', 'POLICE', 'POLICE', 'POLICE', 'FIRE', 'CITY COUNCIL', 'POLICE', 'FIRE', 'POLICE', 'POLICE', 'POLICE', 'TRANSPORTN', 'POLICE', 'OEMC', 'FIRE', 'POLICE', 'BUSINESS AFFAIRS', 'POLICE', 'AVIATION', 'POLICE', 'POLICE', 'POLICE', 'POLICE', 'LAW', 'POLICE', 'FIRE', 'FIRE', 'OEMC', 'POLICE', 'POLICE', 'POLICE', 'PUBLIC LIBRARY', 'POLICE', 'POLICE', 'STREETS & Sanitary', 'AVIATION', 'GENERALERAL SERVICES', 'POLICE', 'POLICE', 'STREETS & Sanitary', 'PUBLIC LIBRARY', 'FINANCE', 'FIRE', 'AVIATION', 'POLICE', 'POLICE', 'FIRE', 'TRANSPORTN', 'FIRE', 'STREETS & Sanitary', 'POLICE', 'CULTURAL AFFAIRS', 'PUBLIC LIBRARY', 'HEALTH', 'POLICE', 'POLICE', 'OEMC', 'TRANSPORTN', 'WATER MANAGEMENT', 'STREETS & Sanitary', 'AVIATION', 'BUSINESS AFFAIRS', 'TRANSPORTN', 'POLICE', 'POLICE', 'FIRE', 'FIRE', 'POLICE', 'CommunityUNITY DEVELOPMENT', 'PUBLIC LIBRARY', 'POLICE', 'POLICE', 'GENERALERAL SERVICES', 'LAW', 'STREETS & Sanitary', 'HEALTH', 'FIRE', 'BUILDINGS', 'BUILDINGS', 'OEMC', 'POLICE', 'PUBLIC LIBRARY', 'BUSINESS AFFAIRS', 'TRANSPORTN', 'HEALTH', 'POLICE', 'POLICE', 'FINANCE', 'POLICE', 'TRANSPORTN', 'STREETS & Sanitary', 'IPRA', 'PUBLIC LIBRARY', 'PUBLIC LIBRARY', 'POLICE', 'BUILDINGS', 'POLICE', 'POLICE', 'HEALTH', 'POLICE', 'BUSINESS AFFAIRS', 'CITY COUNCIL', 'FINANCE', 'HEALTH', 'WATER MANAGEMENT', 'TRANSPORTN', 'HEALTH', 'LAW', 'OEMC', 'POLICE', 'OEMC', 'PUBLIC LIBRARY', 'POLICE', 'POLICE', 'BUSINESS AFFAIRS', 'POLICE', 'FIRE', 'POLICE', 'AVIATION', 'POLICE', 'HEALTH', 'WATER MANAGEMENT', 'POLICE', 'POLICE', 'AVIATION', 'POLICE', 'FIRE', 'POLICE', 'TRANSPORTN', 'POLICE', 'POLICE', 'STREETS & Sanitary', 'STREETS & Sanitary', 'POLICE', 'POLICE', 'FIRE', 'FIRE', 'HEALTH', 'LAW', 'STREETS & Sanitary', 'STREETS & Sanitary', 'ANIMAL Control', 'HEALTH', 'AVIATION', 'STREETS & Sanitary', 'FIRE', 'STREETS & Sanitary', 'AVIATION', 'CITY CLERK', 'POLICE', 'BOARD OF ELECTION', 'POLICE', 'POLICE', 'ANIMAL Control', 'STREETS & Sanitary', 'POLICE', 'STREETS & Sanitary', 'TRANSPORTN', 'POLICE', 'POLICE', 'POLICE', 'POLICE', 'POLICE', 'STREETS & Sanitary', 'POLICE', 'POLICE', 'TRANSPORTN', 'POLICE', 'POLICE', 'POLICE', 'WATER MANAGEMENT', 'AVIATION', 'POLICE', 'POLICE', 'TRANSPORTN', 'POLICE', 'BUSINESS AFFAIRS', 'PUBLIC LIBRARY', 'POLICE', 'FIRE', 'FIRE', 'POLICE', 'POLICE', 'FIRE', 'FIRE', 'POLICE', 'AVIATION', 'LAW', 'INSPECTOR GENERAL', 'WATER MANAGEMENT', 'FINANCE', 'POLICE', 'AVIATION', 'POLICE', 'CommunityUNITY DEVELOPMENT', 'TRANSPORTN', 'TRANSPORTN', 'CITY COUNCIL', 'POLICE', 'FIRE', 'POLICE', 'HEALTH', 'POLICE', 'POLICE', 'POLICE', 'PUBLIC LIBRARY', 'AVIATION', 'STREETS & Sanitary', 'STREETS & Sanitary', 'FAMILY & SUPPORT', 'BOARD OF ELECTION', 'POLICE', 'FIRE', 'POLICE', 'TREASURER', 'GENERALERAL SERVICES', 'POLICE', 'OEMC', "MAYOR'S OFFICE", 'POLICE', 'POLICE', 'STREETS & Sanitary', 'TRANSPORTN', 'POLICE', 'POLICE', 'OEMC', 'POLICE', 'POLICE', 'POLICE', 'POLICE', 'HEALTH', 'FAMILY & SUPPORT', 'FIRE', 'FINANCE', 'POLICE', 'GENERALERAL SERVICES', 'POLICE', 'POLICE', 'POLICE', 'POLICE', 'POLICE', 'AVIATION', 'FIRE', 'HEALTH', 'CommunityUNITY DEVELOPM ...

# %%
chicago.head()
chicago.insert(loc=4,column="Formatted Dept Name",value=new_modified_names)
chicago.head()
# Out:
#                   Name       Formatted Name            Position Title  \
# 0      AARON,  ELVIA J      Aaron,  Elvia J          WATER RATE TAKER
# 1    AARON,  JEFFERY M    Aaron,  Jeffery M            POLICE OFFICER
# 2       AARON,  KARINA       Aaron,  Karina            POLICE OFFICER
# 3  AARON,  KIMBERLEI R  Aaron,  Kimberlei R  CHIEF CONTRACT EXPEDITER
# 4  ABAD JR,  VICENTE M  Abad Jr,  Vicente M         CIVIL ENGINEER IV
#
#          Department   Formatted Dept Name Employee Annual Salary
# 0       WATER MGMNT      WATER MANAGEMENT              $90744.00
# 1            POLICE                POLICE              $84450.00
# 2            POLICE                POLICE              $84450.00
# 3  GENERAL SERVICES  GENERALERAL SERVICES              $89880.00
# 4       WATER MGMNT      WATER MANAGEMENT             $106836.00

# %%
chicago["Formatted Dept Name"] = chicago["Formatted Dept Name"].str.title()
chicago.head()
# Out:
#                   Name       Formatted Name            Position Title  \
# 0      AARON,  ELVIA J      Aaron,  Elvia J          WATER RATE TAKER
# 1    AARON,  JEFFERY M    Aaron,  Jeffery M            POLICE OFFICER
# 2       AARON,  KARINA       Aaron,  Karina            POLICE OFFICER
# 3  AARON,  KIMBERLEI R  Aaron,  Kimberlei R  CHIEF CONTRACT EXPEDITER
# 4  ABAD JR,  VICENTE M  Abad Jr,  Vicente M         CIVIL ENGINEER IV
#
#          Department   Formatted Dept Name Employee Annual Salary
# 0       WATER MGMNT      Water Management              $90744.00
# 1            POLICE                Police              $84450.00
# 2            POLICE                Police              $84450.00
# 3  GENERAL SERVICES  Generaleral Services              $89880.00
# 4       WATER MGMNT      Water Management             $106836.00

# %%
chicago.tail()
# Out:
#                       Name       Formatted Name  \
# 32057  ZYGADLO,  MICHAEL J  Zygadlo,  Michael J
# 32058   ZYGOWICZ,  PETER J   Zygowicz,  Peter J
# 32059    ZYMANTAS,  MARK E    Zymantas,  Mark E
# 32060  ZYRKOWSKI,  CARLO E  Zyrkowski,  Carlo E
# 32061  ZYSKOWSKI,  DARIUSZ  Zyskowski,  Dariusz
#
#                        Position Title        Department   Formatted Dept Name  \
# 32057  FRM OF MACHINISTS - AUTOMOTIVE  GENERAL SERVICES  Generaleral Services
# 32058                  POLICE OFFICER            POLICE                Police
# 32059                  POLICE OFFICER            POLICE                Police
# 32060                  POLICE OFFICER            POLICE                Police
# 32061         CHIEF DATA BASE ANALYST              DoIT            Dept Of It
#
#       Employee Annual Salary
# 32057              $99528.00
# 32058              $87384.00
# 32059              $84450.00
# 32060              $87384.00
# 32061             $113664.00

# %% [markdown]
# ## Filtering with String Methods
# - The `str.contains` method checks whether a substring exists anywhere in the string.
# - The `str.startswith` method checks whether a substring exists at the start of the string.
# - The `str.endswith` method checks whether a substring exists at the end of the string.
#
# ##### Ensure to normalize the string characters before passing the filter conditions

# %%
# Searching for employee's whose title contains 'water' in their position title
# condition
has_water = chicago["Position Title"].str.lower().str.contains("water")
chicago[has_water]
# Out:
#                        Name        Formatted Name  \
# 0           AARON,  ELVIA J       Aaron,  Elvia J
# 554      ALUISE,  VINCENT G    Aluise,  Vincent G
# 671         ANDER,  PERRY A       Ander,  Perry A
# 685     ANDERSON,  ANDREW J   Anderson,  Andrew J
# 702       ANDERSON,  DONALD     Anderson,  Donald
# ...                     ...                   ...
# 29669        VERMA,  ANUPAM        Verma,  Anupam
# 30239   WASHINGTON,  JOSEPH   Washington,  Joseph
# 30544       WEST,  THOMAS R       West,  Thomas R
# 30991    WILLIAMS,  MATTHEW    Williams,  Matthew
# 31405  WOODRIDGE,  ROBERT L  Woodridge,  Robert L
#
#                                       Position Title   Department  \
# 0                                   WATER RATE TAKER  WATER MGMNT
# 554               FOREMAN OF WATER PIPE CONSTRUCTION  WATER MGMNT
# 671                                 WATER CHEMIST II  WATER MGMNT
# 685    DISTRICT SUPERINTENDENT OF WATER DISTRIBUTION  WATER MGMNT
# 702               FOREMAN OF WATER PIPE CONSTRUCTION  WATER MGMNT
# ...                                              ...          ...
# 29669           MANAGING ENGINEER - WATER MANAGEMENT  WATER MGMNT
# 30239                              WATER CHEMIST III  WATER MGMNT
# 30544                   GEN SUPT OF WATER MANAGEMENT  WATER MGMNT
# 30991             FOREMAN OF WATER PIPE CONSTRUCTION  WATER MGMNT
# 31405             FOREMAN OF WATER PIPE CONSTRUCTION  WATER MGMNT
#
#       Formatted Dept Name Employee Annual Salary
# 0        Water Management              $90744.00
# 554      Water Management             $102440.00
# 671      Water Management              $82044.00
# 685      Water Management             $109272.00
# 702      Water Management             $102440.00
# ...                   ...                    ...
# 29669    Water Management             $111192.00
# 30239    Water Management              $89676.00
# 30544    Water Management             $115704.00
# 30991    Water Management             $102440.00
# 31405    Water Management             $102440.00
#
# [111 rows x 6 columns]

# %%
# Filter employes whose title starts with 'Civil'
contains_civil = chicago["Position Title"].str.lower().str.startswith("civil")
chicago[contains_civil]
# Out:
#                        Name        Formatted Name      Position Title  \
# 4       ABAD JR,  VICENTE M   Abad Jr,  Vicente M   CIVIL ENGINEER IV
# 25     ABDULSATTAR,  MUDHAR  Abdulsattar,  Mudhar   CIVIL ENGINEER II
# 34       ABRAHAM,  GIRLEY T    Abraham,  Girley T   CIVIL ENGINEER IV
# 55       ABUTALEB,  AHMAD H    Abutaleb,  Ahmad H   CIVIL ENGINEER II
# 147        ADAMS,  TANERA C      Adams,  Tanera C   CIVIL ENGINEER IV
# ...                     ...                   ...                 ...
# 31623         YANG,  LUYANG         Yang,  Luyang    CIVIL ENGINEER V
# 31656         YEPEZ,  JESUS         Yepez,  Jesus   CIVIL ENGINEER IV
# 31662  YESUFU,  STEPHANIE A  Yesufu,  Stephanie A  CIVIL ENGINEER III
# 31797       ZAKE,  JOSHUA S       Zake,  Joshua S   CIVIL ENGINEER IV
# 31935          ZHANG,  ANNE          Zhang,  Anne  CIVIL ENGINEER III
#
#         Department Formatted Dept Name Employee Annual Salary
# 4      WATER MGMNT    Water Management             $106836.00
# 25     WATER MGMNT    Water Management              $58536.00
# 34     WATER MGMNT    Water Management             $106836.00
# 55     WATER MGMNT    Water Management              $89676.00
# 147     TRANSPORTN          Transportn             $106836.00
# ...            ...                 ...                    ...
# 31623   TRANSPORTN          Transportn             $116784.00
# 31656   TRANSPORTN          Transportn             $106836.00
# 31662   TRANSPORTN          Transportn              $92784.00
# 31797   TRANSPORTN          Transportn             $106836.00
# 31935   TRANSPORTN          Transportn              $77364.00
#
# [70 rows x 6 columns]

# %%
# Filter employes whose title ends with 'IV'
contains_iv = chicago["Position Title"].str.lower().str.endswith("iv")
chicago[contains_iv]
# Out:
#                         Name         Formatted Name          Position Title  \
# 4        ABAD JR,  VICENTE M    Abad Jr,  Vicente M       CIVIL ENGINEER IV
# 34        ABRAHAM,  GIRLEY T     Abraham,  Girley T       CIVIL ENGINEER IV
# 145        ADAMS,  SHERYLL A      Adams,  Sheryll A            LIBRARIAN IV
# 147         ADAMS,  TANERA C       Adams,  Tanera C       CIVIL ENGINEER IV
# 166        ADENI,  MOHAMED K      Adeni,  Mohamed K           ACCOUNTANT IV
# ...                      ...                    ...                     ...
# 31777  ZAFIRIS,  CHRISTOPHER  Zafiris,  Christopher            ARCHITECT IV
# 31797        ZAKE,  JOSHUA S        Zake,  Joshua S       CIVIL ENGINEER IV
# 31870      ZAVALA,  FERNANDO      Zavala,  Fernando           ACCOUNTANT IV
# 31884       ZAWADSKI,  JAMES       Zawadski,  James                CLERK IV
# 32008        ZOTTA,  SANDINO        Zotta,  Sandino  MECHANICAL ENGINEER IV
#
#            Department Formatted Dept Name Employee Annual Salary
# 4         WATER MGMNT    Water Management             $106836.00
# 34        WATER MGMNT    Water Management             $106836.00
# 145    PUBLIC LIBRARY      Public Library              $97812.00
# 147        TRANSPORTN          Transportn             $106836.00
# 166           FINANCE             Finance              $97812.00
# ...               ...                 ...                    ...
# 31777    DISABILITIES        Disabilities             $106836.00
# 31797      TRANSPORTN          Transportn             $106836.00
# 31870         FINANCE             Finance              $97812.00
# 31884             LAW                 Law              $68028.00
# 32008     WATER MGMNT    Water Management             $106836.00
#
# [274 rows x 6 columns]

# %% [markdown]
# ## String Methods on Index and Columns
# - Use the `index` and `columns` attributes to access the **DataFrame** index/column labels.
# - These objects support string methods via their own `str` attribute.

# %%
# Resetting the dataset & defining Names as the index
chicago = pd.read_csv("chicago.csv",index_col=["Name"]).dropna(how="all").sort_index()
chicago["Department"] = chicago["Department"].astype("category")
chicago.head()
# Out:
#                                Position Title        Department  \
# Name
# AARON,  ELVIA J              WATER RATE TAKER       WATER MGMNT
# AARON,  JEFFERY M              POLICE OFFICER            POLICE
# AARON,  KARINA                 POLICE OFFICER            POLICE
# AARON,  KIMBERLEI R  CHIEF CONTRACT EXPEDITER  GENERAL SERVICES
# ABAD JR,  VICENTE M         CIVIL ENGINEER IV       WATER MGMNT
#
#                     Employee Annual Salary
# Name
# AARON,  ELVIA J                  $90744.00
# AARON,  JEFFERY M                $84450.00
# AARON,  KARINA                   $84450.00
# AARON,  KIMBERLEI R              $89880.00
# ABAD JR,  VICENTE M             $106836.00

# %%
chicago.index.str.title()
# Out:
# Index(['Aaron,  Elvia J', 'Aaron,  Jeffery M', 'Aaron,  Karina',
#        'Aaron,  Kimberlei R', 'Abad Jr,  Vicente M', 'Abarca,  Anabel',
#        'Abarca,  Emmanuel', 'Abascal,  Reece E', 'Abbasi,  Christopher',
#        'Abbatacola,  Robert J',
#        ...
#        'Zwit,  Jeffrey J', 'Zwolfer,  Matthew W', 'Zych,  Mateusz',
#        'Zydek,  Bryan', 'Zygadlo,  John P', 'Zygadlo,  Michael J',
#        'Zygowicz,  Peter J', 'Zymantas,  Mark E', 'Zyrkowski,  Carlo E',
#        'Zyskowski,  Dariusz'],
#       dtype='object', name='Name', length=32062)

# %%
chicago.columns.str.upper()
# Out:
# Index(['POSITION TITLE', 'DEPARTMENT', 'EMPLOYEE ANNUAL SALARY'], dtype='object')

# %% [markdown]
# ## The split Method
# - The `str.split` method splits a string by the occurrence of a delimiter. Pandas returns a **Series** of lists.
# - Use the `str.get` method to access a nested list element by its index position.

# %%
"The quick brown fox".split(sep=" ")
# Out:
# ['The', 'quick', 'brown', 'fox']

# %%
# Most common fist word in chicago position titles
chicago["Position Title"].str.split(" ").str.get(0).value_counts()
# Out:
# Position Title
# POLICE             10856
# FIREFIGHTER-EMT     1509
# SERGEANT            1186
# POOL                 918
# FIREFIGHTER          810
#                    ...
# PORTFOLIO              1
# SUPERVISOR             1
# SUPT                   1
# STRUCTURAL             1
# CORPORATION            1
# Name: count, Length: 320, dtype: int64

# %%
# Most common first name
newone = chicago["Formatted Name"].str.split(",").str.get(-1)
# intermediate series to further seggregate instances that contain [FirstName + MiddleName]
newone.str.lstrip().str.split(" ").str.get(0).value_counts()
# Out:
# Formatted Name
# Michael     1153
# John         899
# James        676
# Robert       622
# Joseph       537
#             ...
# Russ           1
# Fabiola        1
# Jurdon         1
# Nateesha       1
# Lilya          1
# Name: count, Length: 5091, dtype: int64

# %% [markdown]
# ## More Practice with Splits

# %%
# Another approach for extracting first names
chicago["Formatted Name"].str.split(", ").str.get(1).str.strip().str.split(" ").str.get(0)
chicago["Formatted Name"].str.split(", ").str.get(1).str.strip().str.split(" ").str.get(0).value_counts()
# Out:
# Formatted Name
# Michael     1153
# John         899
# James        676
# Robert       622
# Joseph       537
#             ...
# Russ           1
# Fabiola        1
# Jurdon         1
# Nateesha       1
# Lilya          1
# Name: count, Length: 5091, dtype: int64

# %% [markdown]
# ## The expand and n Parameters of the split Method
# - The `expand` parameter returns a **DataFrame** instead of a **Series** of lists.
# - The `n` parameter limits the number of splits.

# %%
chicago[["LastName","FirstName"]]=chicago["Formatted Name"].str.split(", ",expand=True)
chicago.head()
# Out:
#                   Name       Formatted Name            Position Title  \
# 0      AARON,  ELVIA J      Aaron,  Elvia J          WATER RATE TAKER
# 1    AARON,  JEFFERY M    Aaron,  Jeffery M            POLICE OFFICER
# 2       AARON,  KARINA       Aaron,  Karina            POLICE OFFICER
# 3  AARON,  KIMBERLEI R  Aaron,  Kimberlei R  CHIEF CONTRACT EXPEDITER
# 4  ABAD JR,  VICENTE M  Abad Jr,  Vicente M         CIVIL ENGINEER IV
#
#          Department Employee Annual Salary LastName     FirstName
# 0       WATER MGMNT              $90744.00    Aaron       Elvia J
# 1            POLICE              $84450.00    Aaron     Jeffery M
# 2            POLICE              $84450.00    Aaron        Karina
# 3  GENERAL SERVICES              $89880.00    Aaron   Kimberlei R
# 4       WATER MGMNT             $106836.00  Abad Jr     Vicente M

# %%
chicago["Formatted Name"].str.split(" ",expand=True,n=2).rename(columns={0:"last name",1:"middle name",2:"first name"})
# Out:
#         last name middle name   first name
# 0          Aaron,                  Elvia J
# 1          Aaron,                Jeffery M
# 2          Aaron,                   Karina
# 3          Aaron,              Kimberlei R
# 4            Abad         Jr,    Vicente M
# ...           ...         ...          ...
# 32057    Zygadlo,                Michael J
# 32058   Zygowicz,                  Peter J
# 32059   Zymantas,                   Mark E
# 32060  Zyrkowski,                  Carlo E
# 32061  Zyskowski,                  Dariusz
#
# [32062 rows x 3 columns]

# %% [markdown]
# ##### *End of DataFrame String methods*
